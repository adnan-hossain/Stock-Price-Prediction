# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#importing packages
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Lambda, Bidirectional, GRU, Conv1D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
#setting figure size
rcParams['figure.figsize'] = 20,10

#for normalizing data
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('/content/drive/My Drive/DATA/TESLA_JULY15_JULY20.csv')

#df['Date'] = df[['Date', 'Time']].apply(lambda x: '-'.join(x), axis=1)
#print the head
df
# Out:
#            Date         Open         High  ...        Close    Adj Close    Volume
# 0     7/24/2015   267.380005   271.089996  ...   265.410004   265.410004   2836500
# 1     7/27/2015   262.429993   264.429993  ...   253.009995   253.009995   4694200
# 2     7/28/2015   255.750000   265.399994  ...   264.820007   264.820007   3895800
# 3     7/29/2015   264.269989   267.890015  ...   263.820007   263.820007   2790100
# 4     7/30/2015   262.690002   266.940002  ...   266.790009   266.790009   2034600
# ...         ...          ...          ...  ...          ...          ...       ...
# 1254  7/17/2020  1513.449951  1537.510010  ...  1500.839966  1500.839966   9330000
# 1255  7/20/2020  1519.010010  1650.000000  ...  1643.000000  1643.000000  17121400
# 1256  7/21/2020  1639.930054  1675.000000  ...  1568.359985  1568.359985  16157300
# 1257  7/22/2020  1599.000000  1626.420044  ...  1592.329956  1592.329956  14161100
# 1258  7/23/2020  1678.949951  1689.000000  ...  1513.069946  1513.069946  24203600
#
# [1259 rows x 7 columns]

# %%
#setting index as date
#df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df['Date'] = pd.to_datetime(df.Date)
df.index = df['Date']
#df = df[df['Date'] < '2020-01-01']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')
plt.legend()

# %%
#creating dataframe
T = 30 #training period
T_pred = 1 #prediction period

data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

train = dataset[:-T_pred,:]
valid = dataset[-T_pred:,:]

len(train), len(valid)
# Out:
# (1258, 1)

# %%
#converting dataset into x_train and y_train
# T = 30 #training period
# T_pred = T
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(T,len(train)-T_pred):
    x_train.append(scaled_data[i-T:i,0])
    y_train.append(scaled_data[i:i+T_pred,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
#y_train = np.reshape(y_train, (y_train.shape[0],y_train.shape[1],1))
print(x_train.shape, y_train.shape)
# Out:
# (1227, 30, 1) (1227, 1)

# %%
# create and fit the LSTM network
model_name = '4_CONV_1_LSTM_4_DENSE_SPY_JULY15_JAN20'
weight_save_path = '/content/drive/My Drive/CNN/Results/'

model = Sequential()
model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [T,1]))
model.add(BatchNormalization())
model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(filters=150, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(filters=150, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
model.add(LSTM(units=150, activation='tanh'))
model.add(Dense(100))
model.add(Dropout(0.2))
model.add(Dense(50))
model.add(Dropout(0.1))
model.add(Dense(20))
model.add(Dense(T_pred))
#model.add(Lambda(lambda x: x*500))


model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001), metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 30, 300)           1800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 300)           1200
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 30, 300)           450300
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30, 300)           1200
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 30, 150)           225150
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 30, 150)           600
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 30, 150)           112650
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 150)           600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 150)               180600
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               15100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 995,291
# Trainable params: 993,491
# Non-trainable params: 1,800
# _________________________________________________________________

# %%
#callbacks
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
checkpoint = ModelCheckpoint(weight_save_path+model_name+'.h5', monitor='loss', save_best_only=True, save_weights_only=True, )

# %%
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=[lr_schedule])
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 23ms/step - loss: 0.5290 - mae: 0.5900 - lr: 1.0000e-08
# Epoch 2/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.5260 - mae: 0.5866 - lr: 1.1220e-08
# Epoch 3/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5257 - mae: 0.5877 - lr: 1.2589e-08
# Epoch 4/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5254 - mae: 0.5897 - lr: 1.4125e-08
# Epoch 5/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5357 - mae: 0.5943 - lr: 1.5849e-08
# Epoch 6/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5185 - mae: 0.5851 - lr: 1.7783e-08
# Epoch 7/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5255 - mae: 0.5888 - lr: 1.9953e-08
# Epoch 8/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5267 - mae: 0.5891 - lr: 2.2387e-08
# Epoch 9/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5255 - mae: 0.5869 - lr: 2.5119e-08
# Epoch 10/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.5210 - mae: 0.5858 - lr: 2.8184e-08
# Epoch 11/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5199 - mae: 0.5859 - lr: 3.1623e-08
# Epoch 12/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5251 - mae: 0.5896 - lr: 3.5481e-08
# Epoch 13/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5103 - mae: 0.5797 - lr: 3.9811e-08
# Epoch 14/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5108 - mae: 0.5812 - lr: 4.4668e-08
# Epoch 15/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5132 - mae: 0.5832 - lr: 5.0119e-08
# Epoch 16/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4982 - mae: 0.5741 - lr: 5.6234e-08
# Epoch 17/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5092 - mae: 0.5799 - lr: 6.3096e-08
# Epoch 18/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5056 - mae: 0.5781 - lr: 7.0795e-08
# Epoch 19/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4938 - mae: 0.5713 - lr: 7.9433e-08
# Epoch 20/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4922 - mae: 0.5727 - lr: 8.9125e-08
# Epoch 21/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4962 - mae: 0.5719 - lr: 1.0000e-07
# Epoch 22/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.4905 - mae: 0.5698 - lr: 1.1220e-07
# Epoch 23/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4797 - mae: 0.5650 - lr: 1.2589e-07
# Epoch 24/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4743 - mae: 0.5614 - lr: 1.4125e-07
# Epoch 25/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4700 - mae: 0.5593 - lr: 1.5849e-07
# Epoch 26/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4601 - mae: 0.5531 - lr: 1.7783e-07
# Epoch 27/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4580 - mae: 0.5527 - lr: 1.9953e-07
# Epoch 28/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4473 - mae: 0.5464 - lr: 2.2387e-07
# Epoch 29/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4439 - mae: 0.5437 - lr: 2.5119e-07
# Epoch 30/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4335 - mae: 0.5392 - lr: 2.8184e-07
# Epoch 31/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4231 - mae: 0.5334 - lr: 3.1623e-07
# Epoch 32/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4115 - mae: 0.5258 - lr: 3.5481e-07
# Epoch 33/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4009 - mae: 0.5192 - lr: 3.9811e-07
# Epoch 34/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3964 - mae: 0.5173 - lr: 4.4668e-07
# Epoch 35/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3829 - mae: 0.5087 - lr: 5.0119e-07
# Epoch 36/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3726 - mae: 0.5009 - lr: 5.6234e-07
# Epoch 37/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3689 - mae: 0.4999 - lr: 6.3096e-07
# Epoch 38/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3554 - mae: 0.4914 - lr: 7.0795e-07
# Epoch 39/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3512 - mae: 0.4877 - lr: 7.9433e-07
# Epoch 40/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3409 - mae: 0.4808 - lr: 8.9125e-07
# Epoch 41/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3376 - mae: 0.4798 - lr: 1.0000e-06
# Epoch 42/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3279 - mae: 0.4730 - lr: 1.1220e-06
# Epoch 43/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3225 - mae: 0.4684 - lr: 1.2589e-06
# Epoch 44/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3144 - mae: 0.4623 - lr: 1.4125e-06
# Epoch 45/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3096 - mae: 0.4596 - lr: 1.5849e-06
# Epoch 46/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3030 - mae: 0.4543 - lr: 1.7783e-06
# Epoch 47/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2998 - mae: 0.4525 - lr: 1.9953e-06
# Epoch 48/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2943 - mae: 0.4493 - lr: 2.2387e-06
# Epoch 49/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2876 - mae: 0.4458 - lr: 2.5119e-06
# Epoch 50/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2813 - mae: 0.4398 - lr: 2.8184e-06
# Epoch 51/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2818 - mae: 0.4402 - lr: 3.1623e-06
# Epoch 52/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2763 - mae: 0.4357 - lr: 3.5481e-06
# Epoch 53/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2695 - mae: 0.4300 - lr: 3.9811e-06
# Epoch 54/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2663 - mae: 0.4264 - lr: 4.4668e-06
# Epoch 55/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2620 - mae: 0.4233 - lr: 5.0119e-06
# Epoch 56/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2601 - mae: 0.4211 - lr: 5.6234e-06
# Epoch 57/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2541 - mae: 0.4170 - lr: 6.3096e-06
# Epoch 58/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2506 - mae: 0.4131 - lr: 7.0795e-06
# Epoch 59/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2480 - mae: 0.4110 - lr: 7.9433e-06
# Epoch 60/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2437 - mae: 0.4070 - lr: 8.9125e-06
# Epoch 61/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2399 - mae: 0.4031 - lr: 1.0000e-05
# Epoch 62/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2350 - mae: 0.3975 - lr: 1.1220e-05
# Epoch 63/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2315 - mae: 0.3945 - lr: 1.2589e-05
# Epoch 64/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2272 - mae: 0.3893 - lr: 1.4125e-05
# Epoch 65/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2238 - mae: 0.3860 - lr: 1.5849e-05
# Epoch 66/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2188 - mae: 0.3789 - lr: 1.7783e-05
# Epoch 67/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2139 - mae: 0.3744 - lr: 1.9953e-05
# Epoch 68/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2086 - mae: 0.3683 - lr: 2.2387e-05
# Epoch 69/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2046 - mae: 0.3634 - lr: 2.5119e-05
# Epoch 70/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1985 - mae: 0.3559 - lr: 2.8184e-05
# Epoch 71/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1931 - mae: 0.3500 - lr: 3.1623e-05
# Epoch 72/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1864 - mae: 0.3410 - lr: 3.5481e-05
# Epoch 73/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1785 - mae: 0.3324 - lr: 3.9811e-05
# Epoch 74/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1700 - mae: 0.3217 - lr: 4.4668e-05
# Epoch 75/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1608 - mae: 0.3102 - lr: 5.0119e-05
# Epoch 76/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1528 - mae: 0.3002 - lr: 5.6234e-05
# Epoch 77/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1412 - mae: 0.2880 - lr: 6.3096e-05
# Epoch 78/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1317 - mae: 0.2765 - lr: 7.0795e-05
# Epoch 79/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1193 - mae: 0.2614 - lr: 7.9433e-05
# Epoch 80/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1081 - mae: 0.2477 - lr: 8.9125e-05
# Epoch 81/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0973 - mae: 0.2341 - lr: 1.0000e-04
# Epoch 82/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0862 - mae: 0.2201 - lr: 1.1220e-04
# Epoch 83/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0743 - mae: 0.2038 - lr: 1.2589e-04
# Epoch 84/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0657 - mae: 0.1915 - lr: 1.4125e-04
# Epoch 85/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0558 - mae: 0.1767 - lr: 1.5849e-04
# Epoch 86/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0496 - mae: 0.1668 - lr: 1.7783e-04
# Epoch 87/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0446 - mae: 0.1581 - lr: 1.9953e-04
# Epoch 88/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0421 - mae: 0.1535 - lr: 2.2387e-04
# Epoch 89/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0364 - mae: 0.1429 - lr: 2.5119e-04
# Epoch 90/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0337 - mae: 0.1382 - lr: 2.8184e-04
# Epoch 91/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0314 - mae: 0.1346 - lr: 3.1623e-04
# Epoch 92/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0302 - mae: 0.1297 - lr: 3.5481e-04
# Epoch 93/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0272 - mae: 0.1243 - lr: 3.9811e-04
# Epoch 94/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0260 - mae: 0.1210 - lr: 4.4668e-04
# Epoch 95/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0235 - mae: 0.1165 - lr: 5.0119e-04
# Epoch 96/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0238 - mae: 0.1165 - lr: 5.6234e-04
# Epoch 97/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0230 - mae: 0.1170 - lr: 6.3096e-04
# Epoch 98/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0199 - mae: 0.1079 - lr: 7.0795e-04
# Epoch 99/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0195 - mae: 0.1055 - lr: 7.9433e-04
# Epoch 100/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0207 - mae: 0.1109 - lr: 8.9125e-04
# Run time: 1.0347150564193726

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-2, 0, 1])
#use this to choose the optimum lr and run the NN for 500 epochs
# Out:
# (1e-08, 0.01, 0.0, 1.0)

# %%
class stop_training(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if (logs.get('loss')<0.0005):
      print("Stopping training")
      self.model.stop_training = True
      
stop_training = stop_training()
model.compile(loss='mse', optimizer=Adam(lr=1e-3), metrics=['mae'])
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=400, batch_size=32, callbacks=[checkpoint, stop_training])
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/400
# 39/39 [==============================] - 1s 14ms/step - loss: 0.2125 - mae: 0.2955
# Epoch 2/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0292 - mae: 0.1238
# Epoch 3/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0128 - mae: 0.0816
# Epoch 4/400
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0107 - mae: 0.0685
# Epoch 5/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0081 - mae: 0.0597
# Epoch 6/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0064 - mae: 0.0519
# Epoch 7/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0080 - mae: 0.0534
# Epoch 8/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0054 - mae: 0.0439
# Epoch 9/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0048 - mae: 0.0407
# Epoch 10/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0059 - mae: 0.0423
# Epoch 11/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0040 - mae: 0.0390
# Epoch 12/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0041 - mae: 0.0373
# Epoch 13/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0042 - mae: 0.0368
# Epoch 14/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0039 - mae: 0.0356
# Epoch 15/400
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0028 - mae: 0.0307
# Epoch 16/400
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0037 - mae: 0.0365
# Epoch 17/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0037 - mae: 0.0367
# Epoch 18/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0035 - mae: 0.0318
# Epoch 19/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0021 - mae: 0.0275
# Epoch 20/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0028 - mae: 0.0301
# Epoch 21/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0023 - mae: 0.0286
# Epoch 22/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0020 - mae: 0.0275
# Epoch 23/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0020 - mae: 0.0263
# Epoch 24/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0020 - mae: 0.0260
# Epoch 25/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0024 - mae: 0.0306
# Epoch 26/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0023 - mae: 0.0291
# Epoch 27/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0021 - mae: 0.0245
# Epoch 28/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0023 - mae: 0.0274
# Epoch 29/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0018 - mae: 0.0259
# Epoch 30/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0022 - mae: 0.0264
# Epoch 31/400
# 39/39 [==============================] - 0s 13ms/step - loss: 0.0016 - mae: 0.0239
# Epoch 32/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0022 - mae: 0.0265
# Epoch 33/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0257
# Epoch 34/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0241
# Epoch 35/400
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0014 - mae: 0.0230
# Epoch 36/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0240
# Epoch 37/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0013 - mae: 0.0230
# Epoch 38/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0222
# Epoch 39/400
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0020 - mae: 0.0271
# Epoch 40/400
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0012 - mae: 0.0215
# Epoch 41/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0232
# Epoch 42/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0210
# Epoch 43/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0217
# Epoch 44/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0199
# Epoch 45/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0010 - mae: 0.0198
# Epoch 46/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.2423e-04 - mae: 0.0198
# Epoch 47/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.5563e-04 - mae: 0.0204
# Epoch 48/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.3086e-04 - mae: 0.0191
# Epoch 49/400
# 39/39 [==============================] - 0s 12ms/step - loss: 9.9659e-04 - mae: 0.0204
# Epoch 50/400
# 39/39 [==============================] - 0s 12ms/step - loss: 9.0167e-04 - mae: 0.0201
# Epoch 51/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.9760e-04 - mae: 0.0186
# Epoch 52/400
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0012 - mae: 0.0196
# Epoch 53/400
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0011 - mae: 0.0211
# Epoch 54/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0013 - mae: 0.0209
# Epoch 55/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0010 - mae: 0.0197
# Epoch 56/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0197
# Epoch 57/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0018 - mae: 0.0271
# Epoch 58/400
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0207
# Epoch 59/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.8139e-04 - mae: 0.0207
# Epoch 60/400
# 39/39 [==============================] - 0s 13ms/step - loss: 7.8944e-04 - mae: 0.0181
# Epoch 61/400
# 39/39 [==============================] - 0s 10ms/step - loss: 9.3321e-04 - mae: 0.0188
# Epoch 62/400
# 39/39 [==============================] - 0s 12ms/step - loss: 9.4512e-04 - mae: 0.0202
# Epoch 63/400
# 39/39 [==============================] - 0s 12ms/step - loss: 7.7089e-04 - mae: 0.0174
# Epoch 64/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.1744e-04 - mae: 0.0201
# Epoch 65/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0197
# Epoch 66/400
# 39/39 [==============================] - 1s 13ms/step - loss: 7.6349e-04 - mae: 0.0181
# Epoch 67/400
# 39/39 [==============================] - 0s 10ms/step - loss: 9.2393e-04 - mae: 0.0197
# Epoch 68/400
# 39/39 [==============================] - 0s 11ms/step - loss: 8.8489e-04 - mae: 0.0186
# Epoch 69/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.6076e-04 - mae: 0.0199
# Epoch 70/400
# 39/39 [==============================] - 0s 11ms/step - loss: 9.9146e-04 - mae: 0.0190
# Epoch 71/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0010 - mae: 0.0189
# Epoch 72/400
# 39/39 [==============================] - 1s 13ms/step - loss: 6.2421e-04 - mae: 0.0162
# Epoch 73/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.7983e-04 - mae: 0.0163
# Epoch 74/400
# 39/39 [==============================] - 0s 10ms/step - loss: 8.7928e-04 - mae: 0.0185
# Epoch 75/400
# 39/39 [==============================] - 0s 11ms/step - loss: 8.3780e-04 - mae: 0.0172
# Epoch 76/400
# 39/39 [==============================] - 0s 11ms/step - loss: 7.7640e-04 - mae: 0.0167
# Epoch 77/400
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0184
# Epoch 78/400
# 39/39 [==============================] - 0s 12ms/step - loss: 5.6273e-04 - mae: 0.0158
# Epoch 79/400
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9720e-04 - mae: 0.0159
# Epoch 80/400
# 39/39 [==============================] - 0s 11ms/step - loss: 7.9127e-04 - mae: 0.0178
# Epoch 81/400
# 39/39 [==============================] - 0s 10ms/step - loss: 6.5445e-04 - mae: 0.0165
# Epoch 82/400
# 39/39 [==============================] - 0s 12ms/step - loss: 7.5223e-04 - mae: 0.0178
# Epoch 83/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.1402e-04 - mae: 0.0159
# Epoch 84/400
# 39/39 [==============================] - 0s 11ms/step - loss: 5.9134e-04 - mae: 0.0159
# Epoch 85/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.2649e-04 - mae: 0.0152
# Epoch 86/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.6414e-04 - mae: 0.0167
# Epoch 87/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.0225e-04 - mae: 0.0167
# Epoch 88/400
# 39/39 [==============================] - 0s 13ms/step - loss: 5.5015e-04 - mae: 0.0147
# Epoch 89/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.6005e-04 - mae: 0.0156
# Epoch 90/400
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5593e-04 - mae: 0.0156
# Epoch 91/400
# 39/39 [==============================] - 0s 11ms/step - loss: 6.9785e-04 - mae: 0.0159
# Epoch 92/400
# 35/39 [=========================>....] - ETA: 0s - loss: 4.8024e-04 - mae: 0.0141Stopping training
# 39/39 [==============================] - 0s 12ms/step - loss: 4.6571e-04 - mae: 0.0140
# Run time: 0.746079957485199

# %%
model.load_weights(weight_save_path+model_name+'.h5')

# %%
#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - T:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(T,inputs.shape[0]):
    X_test.append(inputs[i-T:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
inputs = new_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = np.reshape(inputs, (1,-1,1))
X_test.shape
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape
# Out:
# (1, 2)

# %%
print(closing_price.shape)
print(X_test.shape)
print(valid.shape)
# Out:
# (1, 1)
# (1, 30, 1)
# (1, 1)

# %%
#rms error
rms=np.sqrt(np.mean(np.power((valid.reshape(1,-1) - closing_price),2)))
rms
#np.mean(np.abs(valid - closing_price))
# Out:
# 8.791137984374927

# %%
np.std(valid)
# Out:
# 0.0

# %%
#for plotting
train = new_data[:-T_pred]
#train_pred = new_data[T:450]
valid = new_data[-T_pred:]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price.reshape(-1,1)
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
inputs = new_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = np.reshape(inputs, (1,-1,1))
X_test.shape
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape
# Out:
# (1, 1)

# %%
#Predictions on test set
closing_price = np.zeros((len(valid)))
X_test = []
for pred in range(len(closing_price)):
  #Single valued output
  if pred<T:
    X_test = new_data[len(train) - T + pred:len(train)].values
    X_test = X_test.reshape(-1,1)
    X_test = scaler.transform(X_test)
    if pred>0:
      X_test = np.concatenate((X_test, closing_price[:pred]), axis = None)  
  if pred>=T:
    X_test = closing_price[pred - T:pred]
  X_test = np.array(X_test)
  X_test = X_test.reshape(-1,1)
  #X_test  = scaler.transform(X_test)

  X_test = np.reshape(X_test, (X_test.shape[1],X_test.shape[0],1))
  closing_price[pred] = model.predict(X_test)
  #closing_price[pred] = scaler.inverse_transform(closing_price[pred]) 

closing_price = closing_price.reshape(-1,1)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape #single valued output prediction
# Out:
# (1, 1)

# %%
print(closing_price.shape)
print(X_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (292, 1)
# (1, 90, 1)
# (710, 90, 1)
# (710,)

# %%
closing_price

# %%
#rms error
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
#np.mean(np.abs(valid - closing_price))
# Out:
# Close          8.791165
# Predictions    0.000027
# dtype: float64

# %%
#for plotting
train = new_data[:-T_pred]
#train_pred = new_data[T:450]
valid = new_data[-T_pred:]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
valid
# Out:
#               Close
# Date
# 2018-09-26   309.58
# 2018-09-27   307.52
# 2018-09-28   264.77
# 2018-10-01    310.7
# 2018-10-02   301.02
# ...             ...
# 2020-07-17  1500.84
# 2020-07-20     1643
# 2020-07-21  1568.36
# 2020-07-22  1592.33
# 2020-07-23  1513.07
#
# [459 rows x 1 columns]

# %%
valid.to_csv('/content/drive/My Drive/Covid 19 part(2)/Results_1/TESLA_Predicted_vs_Actual_Stock_Prices_JULY.csv')

# %%
#Prediction for 22nd July, 2017
inputs = new_data[len(new_data) - T:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = inputs
X_test = X_test.reshape(1,T,1)

closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
print('Price on 22nd July : {}'.format(closing_price[0][0]))
# Out:
# Price on 22nd July : 1605.862060546875

# %%
#learning rate decay(picking optimum learning rate)
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss='mse', optimizer=optimizer)
history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-3, 0, 300])
#use this to choose the optimum lr and run the NN for 500 epochs

# %%
#Conv1D
tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [None,1])

# %%
#Converting the data in a df to float
df = df.astype('float64')

# %%
#concatenating two colums
data['date_time'] = data['date'].str.cat(data['time'], sep=' ')

# %%
#getting daily data from minute/hour wise data
df = df.resample('D').mean() # if we want mean of time data
df = df.resample('D').sum() # if we want sum of time data

# %%
#evaluate model for multi-step LSTM
def evaluate_model(y_true, y_predicted):
  scores = []

  #calculating score for each day
  for i in range(y_true.shape[1]):
    mse = mean_squared_error(y_true[:, i], y_predicted[:, i])
    rmse = np.sqrt(mse)
    scores.append(rmse)

  #calculating score for whole prediction
  total_score = 0
  for row in range(y_true.shape[0]):
    for col in range(y_predicted.shape[1]):
      total_score = total_score + (y_true[row,col] - y_predicted[row,col])**2
  total_score = np.sqrt(total_score/(y_true.shape[0]*y_predicted.shape[1]))

  return total_ score, scores

evaluate_model(y_true, y_pred)
np.std(y_true[0])

# %%
data = pd.read_csv('/content/drive/My Drive/Covid 19 part(2)/LSTM/AAPL_JAN18_JULY20.csv')
data
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [627 rows x 7 columns]

# %%
data_training = data[data['Date'] < '2019-12-31'].copy()
data_training
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 485  2019-12-23  280.529999  284.250000  ...  284.000000  282.562683  24643000
# 486  2019-12-24  284.690002  284.890015  ...  284.269989  282.831299  12119700
# 487  2019-12-26  284.820007  289.980011  ...  289.910004  288.442780  23280300
# 488  2019-12-27  291.119995  293.970001  ...  289.799988  288.333313  36566500
# 489  2019-12-30  289.459991  292.690002  ...  291.519989  290.044617  36028600
#
# [490 rows x 7 columns]

# %%
data_testing = data[data['Date'] >= '2019-12-31'].copy()
data_testing
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 490  2019-12-31  289.929993  293.679993  ...  293.649994  292.163818  25201400
# 491  2020-01-02  296.239990  300.600006  ...  300.350006  298.829956  33870100
# 492  2020-01-03  297.149994  300.579987  ...  297.429993  295.924713  36580700
# 493  2020-01-06  293.790009  299.959991  ...  299.799988  298.282715  29596800
# 494  2020-01-07  299.839996  300.899994  ...  298.390015  296.879883  27218000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [137 rows x 7 columns]

# %%
training_data = data_training.drop(['Date', 'Adj Close'], axis=1)
training_data
# Out:
#            Open        High         Low       Close    Volume
# 0    178.610001  179.580002  177.410004  178.460007  32425100
# 1    177.300003  177.779999  176.600006  177.000000  27108600
# 2    177.300003  179.440002  176.820007  177.039993  32689100
# 3    177.250000  177.300003  173.199997  174.220001  51105100
# 4    174.509995  174.949997  170.529999  171.110001  41529000
# ..          ...         ...         ...         ...       ...
# 485  280.529999  284.250000  280.369995  284.000000  24643000
# 486  284.690002  284.890015  282.920013  284.269989  12119700
# 487  284.820007  289.980011  284.700012  289.910004  23280300
# 488  291.119995  293.970001  288.119995  289.799988  36566500
# 489  289.459991  292.690002  285.220001  291.519989  36028600
#
# [490 rows x 5 columns]

# %%
scalar = MinMaxScaler()
training_data = scalar.fit_transform(training_data)
training_data.shape
# Out:
# (490, 5)

# %%
x_train = []
y_train = []

T = 60
for i in range(T, training_data.shape[0]):
  x_train.append(training_data[i-T:i])
  y_train.append(training_data[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (430, 60, 5)
# (430,)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, activation='tanh', input_shape=(x_train.shape[1],5)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=100, activation='tanh'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 60, 50)            11200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 91,901
# Trainable params: 91,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
start = time.time()
model.fit(x_train, y_train, epochs=50, batch_size=8)
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0159
# Epoch 2/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0041
# Epoch 3/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0029
# Epoch 4/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0030
# Epoch 5/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 6/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 7/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0024
# Epoch 8/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0024
# Epoch 9/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0038
# Epoch 10/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0022
# Epoch 11/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 12/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 13/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 14/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 15/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 16/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 17/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0017
# Epoch 18/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0018
# Epoch 19/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 20/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 21/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 22/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0016
# Epoch 23/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 24/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 25/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 26/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 27/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 28/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 29/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 30/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 31/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 32/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 33/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0014
# Epoch 34/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 35/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 36/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 37/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 38/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 39/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 40/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 41/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 42/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 43/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 44/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 45/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 46/50
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0011
# Epoch 47/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.8105e-04
# Epoch 48/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.4821e-04
# Epoch 49/50
# 54/54 [==============================] - 2s 40ms/step - loss: 8.9223e-04
# Epoch 50/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0010
# Run time: 1.929036263624827

# %%
past_T_days = data_training.tail(T)

df = past_T_days.append(data_testing, ignore_index = True)
df
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2019-10-04  225.639999  227.490005  ...  227.009995  225.185043  34619700
# 1    2019-10-07  226.270004  229.929993  ...  227.059998  225.234634  30576500
# 2    2019-10-08  225.820007  228.059998  ...  224.399994  222.596024  27955000
# 3    2019-10-09  227.029999  227.789993  ...  227.029999  225.204895  18692600
# 4    2019-10-10  227.929993  230.440002  ...  230.089996  228.240280  28253400
# ..          ...         ...         ...  ...         ...         ...       ...
# 192  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 193  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 194  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 195  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 196  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [197 rows x 7 columns]

# %%
df = df.drop(['Date', 'Adj Close'], axis=1)
df
# Out:
#            Open        High         Low       Close    Volume
# 0    225.639999  227.490005  223.889999  227.009995  34619700
# 1    226.270004  229.929993  225.839996  227.059998  30576500
# 2    225.820007  228.059998  224.330002  224.399994  27955000
# 3    227.029999  227.789993  225.639999  227.029999  18692600
# 4    227.929993  230.440002  227.300003  230.089996  28253400
# ..          ...         ...         ...         ...       ...
# 192  381.339996  383.920013  378.820007  383.679993  22564300
# 193  389.059998  399.820007  381.029999  381.910004  47912300
# 194  379.359985  389.019989  375.510010  388.230011  42747300
# 195  395.959991  396.989990  385.959991  390.899994  38299500
# 196  386.250000  389.619995  383.619995  386.089996  27644400
#
# [197 rows x 5 columns]

# %%
inputs = scalar.transform(df)
inputs.shape
# Out:
# (197, 5)
