# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#importing packages
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Lambda, Bidirectional, GRU, Conv1D, RepeatVector, TimeDistributed, MaxPooling1D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
#setting figure size
rcParams['figure.figsize'] = 20,10

#for normalizing data
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('/content/drive/My Drive/DATA/SPY_JULY15_JULY20.csv')

#df['Date'] = df[['Date', 'Time']].apply(lambda x: '-'.join(x), axis=1)
#print the head
df
# Out:
#             Date        Open        High  ...       Close   Adj Close     Volume
# 0     2015-07-27  206.940002  207.550003  ...  206.789993  187.214249  132361100
# 1     2015-07-28  207.789993  209.500000  ...  209.330002  189.513840  123544800
# 2     2015-07-29  209.479996  211.039993  ...  210.770004  190.817490  105791300
# 3     2015-07-30  210.160004  211.020004  ...  210.820007  190.862778   91304400
# 4     2015-07-31  211.419998  211.449997  ...  210.500000  190.573059  103266900
# ...          ...         ...         ...  ...         ...         ...        ...
# 1254  2020-07-20  321.429993  325.130005  ...  324.320007  324.320007   56308800
# 1255  2020-07-21  326.450012  326.929993  ...  325.010010  325.010010   57499000
# 1256  2020-07-22  324.619995  327.200012  ...  326.859985  326.859985   57792900
# 1257  2020-07-23  326.470001  327.230011  ...  322.959991  322.959991   75738000
# 1258  2020-07-24  320.950012  321.989990  ...  320.880005  320.880005   73724200
#
# [1259 rows x 7 columns]

# %%
#setting index as date
#df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df['Date'] = pd.to_datetime(df.Date)
df.index = df['Date']
#df = df[df['Date'] < '2020-01-01']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close']/np.max(df['Close']), label='Close Price history')
plt.plot(df['Open']/np.max(df['Open']), label='Open Price history')
plt.plot(df['Volume']/np.max(df['Volume']), label='Sales Volume history')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close'][0:300], label='Close Price history')

# %%
#setting index as date
#df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
# df['Date'] = pd.to_datetime(df.Date)
# df.index = df['Date']
#df = df[df['Date'] < '2020-01-01']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'][-300:]/np.max(df['Close']), label='Close Price history')
plt.plot(df['Open'][-300:]/np.max(df['Open']), label='Open Price history')
plt.plot(df['Volume'][-300:]/np.max(df['Volume']), label='Sales Volume history')
plt.legend()

# %%
#creating dataframe
T = 15 #training period
T_pred = 15 #prediction period

data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values
split_constant = int(0.2*len(dataset)/T_pred)

train = dataset[:-T_pred*split_constant,:]
valid = dataset[-T_pred*split_constant:,:]

len(train), len(valid), split_constant
# Out:
# (1019, 240, 16)

# %%
#converting dataset into x_train and y_train

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(T,len(train)-T_pred):
    x_train.append(scaled_data[i-T:i,0])
    y_train.append(scaled_data[i:i+T_pred,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],y_train.shape[1],1))
print(x_train.shape, y_train.shape)
# Out:
# (989, 15, 1) (989, 15, 1)

# %%
# create and fit the LSTM network
model_name = '15_15_Encoder_Decoder_SPY_JULY15_JAN20'
weight_save_path = '/content/drive/My Drive/LSTM/Results/'

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(T,1)))
#model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(200, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200, activation='tanh'))
model.add(RepeatVector(T_pred))
model.add(LSTM(200, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(100)))
model.add(TimeDistributed(Dense(1)))

model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001), metrics=['mae'])
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 13, 64)            256
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 6, 64)             0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 6, 200)            212000
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 200)            0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 200)               320800
# _________________________________________________________________
# repeat_vector_4 (RepeatVecto (None, 15, 200)           0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 15, 200)           320800
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 200)           0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 15, 200)           320800
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 15, 100)           20100
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 15, 1)             101
# =================================================================
# Total params: 1,194,857
# Trainable params: 1,194,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create and fit the LSTM network
model_name = '30-30_SPY_JULY15_JAN20'
weight_save_path = '/content/drive/My Drive/LSTM/Results/'

model = Sequential()
model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [T,1]))
model.add(BatchNormalization())
# model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu'))
# model.add(BatchNormalization())
model.add(LSTM(units=300, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(LSTM(units=200, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
# # #model.add(BatchNormalization())
model.add(LSTM(units=200, activation='tanh', return_sequences= True))
model.add(Dropout(0.1))
# # #model.add(BatchNormalization())
model.add(LSTM(units=150, activation='tanh', return_sequences= True))
model.add(Dropout(0.1))
# #model.add(BatchNormalization())
model.add(LSTM(units=150, activation='tanh'))
model.add(Dense(100))
model.add(Dropout(0.2))
model.add(Dense(20))
model.add(Dense(T_pred))



model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001), metrics=['mae'])
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 30, 300)           1800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 300)           1200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30, 300)           721200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 300)           0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 300)           1200
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 30, 200)           400800
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30, 200)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 30, 200)           320800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30, 200)           0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 30, 150)           210600
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 150)           0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 150)               180600
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               15100
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                315
# =================================================================
# Total params: 1,855,635
# Trainable params: 1,854,435
# Non-trainable params: 1,200
# _________________________________________________________________

# %%
#callbacks
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
checkpoint = ModelCheckpoint(weight_save_path+model_name+'.h5', monitor='val_loss', save_best_only=True, save_weights_only=True, )
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=100, mode='min',restore_best_weights=True)

# %%
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=[lr_schedule])
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2049 - mae: 0.4027
# Epoch 2/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2048 - mae: 0.4026
# Epoch 3/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2048 - mae: 0.4026
# Epoch 4/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2048 - mae: 0.4025
# Epoch 5/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2048 - mae: 0.4025
# Epoch 6/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2047 - mae: 0.4025
# Epoch 7/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2046 - mae: 0.4024
# Epoch 8/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2046 - mae: 0.4024
# Epoch 9/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2046 - mae: 0.4024
# Epoch 10/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2046 - mae: 0.4023
# Epoch 11/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2045 - mae: 0.4022
# Epoch 12/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2044 - mae: 0.4021
# Epoch 13/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2043 - mae: 0.4020
# Epoch 14/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2042 - mae: 0.4019
# Epoch 15/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2041 - mae: 0.4018
# Epoch 16/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2040 - mae: 0.4017
# Epoch 17/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2039 - mae: 0.4015
# Epoch 18/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2037 - mae: 0.4014
# Epoch 19/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2036 - mae: 0.4012
# Epoch 20/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2034 - mae: 0.4011
# Epoch 21/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2032 - mae: 0.4008
# Epoch 22/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2030 - mae: 0.4005
# Epoch 23/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2027 - mae: 0.4002
# Epoch 24/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2025 - mae: 0.4000
# Epoch 25/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2021 - mae: 0.3996
# Epoch 26/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2018 - mae: 0.3993
# Epoch 27/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2014 - mae: 0.3988
# Epoch 28/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2009 - mae: 0.3983
# Epoch 29/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.2004 - mae: 0.3977
# Epoch 30/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1999 - mae: 0.3971
# Epoch 31/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1992 - mae: 0.3964
# Epoch 32/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1985 - mae: 0.3956
# Epoch 33/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1977 - mae: 0.3947
# Epoch 34/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1968 - mae: 0.3937
# Epoch 35/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1958 - mae: 0.3925
# Epoch 36/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1947 - mae: 0.3913
# Epoch 37/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1933 - mae: 0.3897
# Epoch 38/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1918 - mae: 0.3880
# Epoch 39/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1900 - mae: 0.3860
# Epoch 40/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1881 - mae: 0.3838
# Epoch 41/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1858 - mae: 0.3811
# Epoch 42/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1830 - mae: 0.3779
# Epoch 43/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1798 - mae: 0.3742
# Epoch 44/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1759 - mae: 0.3696
# Epoch 45/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1711 - mae: 0.3640
# Epoch 46/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1653 - mae: 0.3569
# Epoch 47/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1579 - mae: 0.3477
# Epoch 48/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1484 - mae: 0.3356
# Epoch 49/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1359 - mae: 0.3190
# Epoch 50/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1198 - mae: 0.2961
# Epoch 51/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0997 - mae: 0.2641
# Epoch 52/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0777 - mae: 0.2216
# Epoch 53/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0611 - mae: 0.1841
# Epoch 54/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0548 - mae: 0.1742
# Epoch 55/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0530 - mae: 0.1726
# Epoch 56/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0512 - mae: 0.1687
# Epoch 57/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0492 - mae: 0.1644
# Epoch 58/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0472 - mae: 0.1601
# Epoch 59/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0450 - mae: 0.1552
# Epoch 60/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0425 - mae: 0.1493
# Epoch 61/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0398 - mae: 0.1431
# Epoch 62/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0369 - mae: 0.1359
# Epoch 63/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0334 - mae: 0.1263
# Epoch 64/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0296 - mae: 0.1160
# Epoch 65/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0258 - mae: 0.1058
# Epoch 66/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0228 - mae: 0.0996
# Epoch 67/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0207 - mae: 0.0955
# Epoch 68/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0190 - mae: 0.0902
# Epoch 69/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0174 - mae: 0.0854
# Epoch 70/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0156 - mae: 0.0808
# Epoch 71/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0139 - mae: 0.0760
# Epoch 72/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0120 - mae: 0.0705
# Epoch 73/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0100 - mae: 0.0649
# Epoch 74/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0084 - mae: 0.0610
# Epoch 75/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0071 - mae: 0.0582
# Epoch 76/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0059 - mae: 0.0545
# Epoch 77/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0052 - mae: 0.0527
# Epoch 78/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0043 - mae: 0.0498
# Epoch 79/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0036 - mae: 0.0459
# Epoch 80/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0031 - mae: 0.0426
# Epoch 81/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0031 - mae: 0.0428
# Epoch 82/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0029 - mae: 0.0408
# Epoch 83/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0028 - mae: 0.0404
# Epoch 84/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0029 - mae: 0.0414
# Epoch 85/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0029 - mae: 0.0409
# Epoch 86/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0028 - mae: 0.0407
# Epoch 87/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0026 - mae: 0.0389
# Epoch 88/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0026 - mae: 0.0385
# Epoch 89/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0025 - mae: 0.0382
# Epoch 90/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0030 - mae: 0.0422
# Epoch 91/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0032 - mae: 0.0433
# Epoch 92/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0027 - mae: 0.0395
# Epoch 93/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0025 - mae: 0.0384
# Epoch 94/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0026 - mae: 0.0390
# Epoch 95/100
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0025 - mae: 0.0380
# Epoch 96/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0028 - mae: 0.0411
# Epoch 97/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0033 - mae: 0.0443
# Epoch 98/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0032 - mae: 0.0436
# Epoch 99/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0027 - mae: 0.0393
# Epoch 100/100
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0028 - mae: 0.0406
# Run time: 1.3966369350751242

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-2, 0, 1])
#use this to choose the optimum lr and run the NN for 500 epochs
# Out:
# (1e-08, 0.01, 0.0, 1.0)

# %%
class stop_training(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if (logs.get('loss')<0.0005):
      print("Stopping training")
      self.model.stop_training = True
 
stop_training = stop_training()
model.compile(loss='mse', optimizer=Adam(lr=1e-4), metrics=['mae'])
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=2000, batch_size=32, callbacks=[checkpoint, early_stop, stop_training], validation_split=0.1)
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/2000
# 28/28 [==============================] - 2s 87ms/step - loss: 0.0024 - mae: 0.0368 - val_loss: 0.0071 - val_mae: 0.0742
# Epoch 2/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0024 - mae: 0.0370 - val_loss: 0.0058 - val_mae: 0.0671
# Epoch 3/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0356 - val_loss: 0.0032 - val_mae: 0.0481
# Epoch 4/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0023 - mae: 0.0363 - val_loss: 0.0020 - val_mae: 0.0381
# Epoch 5/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0024 - mae: 0.0371 - val_loss: 0.0047 - val_mae: 0.0591
# Epoch 6/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0023 - mae: 0.0364 - val_loss: 0.0065 - val_mae: 0.0709
# Epoch 7/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0022 - mae: 0.0356 - val_loss: 0.0054 - val_mae: 0.0635
# Epoch 8/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0022 - mae: 0.0354 - val_loss: 0.0047 - val_mae: 0.0592
# Epoch 9/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0351 - val_loss: 0.0024 - val_mae: 0.0415
# Epoch 10/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0022 - mae: 0.0358 - val_loss: 0.0041 - val_mae: 0.0549
# Epoch 11/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0021 - mae: 0.0348 - val_loss: 0.0078 - val_mae: 0.0784
# Epoch 12/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0023 - mae: 0.0358 - val_loss: 0.0057 - val_mae: 0.0659
# Epoch 13/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0352 - val_loss: 0.0051 - val_mae: 0.0614
# Epoch 14/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0343 - val_loss: 0.0054 - val_mae: 0.0647
# Epoch 15/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0343 - val_loss: 0.0026 - val_mae: 0.0430
# Epoch 16/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0344 - val_loss: 0.0026 - val_mae: 0.0428
# Epoch 17/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0349 - val_loss: 0.0033 - val_mae: 0.0486
# Epoch 18/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0341 - val_loss: 0.0098 - val_mae: 0.0897
# Epoch 19/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0025 - mae: 0.0383 - val_loss: 0.0023 - val_mae: 0.0402
# Epoch 20/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0024 - mae: 0.0368 - val_loss: 0.0071 - val_mae: 0.0741
# Epoch 21/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0341 - val_loss: 0.0046 - val_mae: 0.0581
# Epoch 22/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0346 - val_loss: 0.0029 - val_mae: 0.0448
# Epoch 23/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0021 - mae: 0.0343 - val_loss: 0.0066 - val_mae: 0.0721
# Epoch 24/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0021 - mae: 0.0340 - val_loss: 0.0073 - val_mae: 0.0761
# Epoch 25/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0352 - val_loss: 0.0047 - val_mae: 0.0594
# Epoch 26/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0021 - mae: 0.0343 - val_loss: 0.0047 - val_mae: 0.0594
# Epoch 27/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0334 - val_loss: 0.0040 - val_mae: 0.0540
# Epoch 28/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0562
# Epoch 29/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0336 - val_loss: 0.0045 - val_mae: 0.0579
# Epoch 30/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0020 - mae: 0.0333 - val_loss: 0.0030 - val_mae: 0.0461
# Epoch 31/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0022 - mae: 0.0351 - val_loss: 0.0040 - val_mae: 0.0536
# Epoch 32/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0057 - val_mae: 0.0658
# Epoch 33/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0333 - val_loss: 0.0025 - val_mae: 0.0420
# Epoch 34/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0336 - val_loss: 0.0061 - val_mae: 0.0682
# Epoch 35/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0020 - mae: 0.0334 - val_loss: 0.0026 - val_mae: 0.0426
# Epoch 36/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0329 - val_loss: 0.0029 - val_mae: 0.0453
# Epoch 37/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0053 - val_mae: 0.0635
# Epoch 38/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0559
# Epoch 39/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0041 - val_mae: 0.0546
# Epoch 40/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0331 - val_loss: 0.0095 - val_mae: 0.0887
# Epoch 41/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 0.0054 - val_mae: 0.0637
# Epoch 42/2000
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0041 - val_mae: 0.0551
# Epoch 43/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0059 - val_mae: 0.0673
# Epoch 44/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0332 - val_loss: 0.0021 - val_mae: 0.0382
# Epoch 45/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 0.0089 - val_mae: 0.0849
# Epoch 46/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0338 - val_loss: 0.0062 - val_mae: 0.0693
# Epoch 47/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0035 - val_mae: 0.0497
# Epoch 48/2000
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0019 - mae: 0.0322 - val_loss: 0.0042 - val_mae: 0.0553
# Epoch 49/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0323 - val_loss: 0.0057 - val_mae: 0.0663
# Epoch 50/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 0.0055 - val_mae: 0.0643
# Epoch 51/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 0.0041 - val_mae: 0.0545
# Epoch 52/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0045 - val_mae: 0.0579
# Epoch 53/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0026 - val_mae: 0.0436
# Epoch 54/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0323 - val_loss: 0.0032 - val_mae: 0.0478
# Epoch 55/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0323 - val_loss: 0.0041 - val_mae: 0.0549
# Epoch 56/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0316 - val_loss: 0.0028 - val_mae: 0.0442
# Epoch 57/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0321 - val_loss: 0.0062 - val_mae: 0.0698
# Epoch 58/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0019 - mae: 0.0323 - val_loss: 0.0059 - val_mae: 0.0678
# Epoch 59/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0311 - val_loss: 0.0063 - val_mae: 0.0698
# Epoch 60/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0039 - val_mae: 0.0536
# Epoch 61/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0312 - val_loss: 0.0026 - val_mae: 0.0432
# Epoch 62/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0031 - val_mae: 0.0471
# Epoch 63/2000
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0018 - mae: 0.0316 - val_loss: 0.0048 - val_mae: 0.0606
# Epoch 64/2000
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0018 - mae: 0.0311 - val_loss: 0.0050 - val_mae: 0.0617
# Run time: 0.9252963582674663

# %%
#Plotting the loss
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='orange')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
model.load_weights(weight_save_path+model_name+'.h5')

# %%
#Predictions on test set
closing_price = np.zeros((len(valid)))
X_test = dataset[-(len(valid)+T):]

for i in range(0,len(valid),T_pred):
  X_test_scaled = scaler.transform(X_test[i:i+T,:])
  X_test_scaled = X_test_scaled.reshape(1,-1,1)
  pred = model.predict(X_test_scaled)
  closing_price[i:i+T_pred] = np.squeeze(pred)

closing_price = closing_price.reshape(-1,1)
closing_price = scaler.inverse_transform(closing_price)

closing_price.shape
# Out:
# (240, 1)

# %%
print(closing_price.shape)
print(X_test.shape)
print(valid.shape)
# Out:
# (240, 1)
# (255, 1)
# (240, 1)

# %%
#rms error
rms = np.sqrt(np.mean(np.power((valid- closing_price),2)))
std = np.std(valid)
print('RMS error of the predictions on validation data: {:.2f}'.format(rms))
print('Standard deviation of the validation data: {:.2f}'.format(std))
# Out:
# RMS error of the predictions on validation data: 22.86
# Standard deviation of the validation data: 21.80

# %%
#Mean Absolute Percentage Error(MAPE)
MAPE = np.sum(np.abs((valid - closing_price)/valid)) / len(valid)
print('MAPE on validation data: {:.2f}'.format(MAPE),'\n')

#Correlation Coefficient R
mean_actual = np.mean(valid)
mean_predicted = np.mean(closing_price)
num = np.sum((valid - mean_actual)*(closing_price - mean_predicted)) 
den = np.sqrt(np.sum(((valid - mean_actual)**2))*np.sum(((closing_price - mean_predicted)**2)))
R = num/den
print('R of validation data: {:.2f}'.format(R), '\n')

#Theil's Inequality Coefficient Theil_U
num = np.sqrt((1/len(valid))*np.sum((valid - closing_price)**2))
den = np.sqrt((1/len(valid))*np.sum(valid**2)) + np.sqrt((1/len(valid))*np.sum(closing_price**2))
Theil_U = num/den
print('Theil U of validation data: {:.2f}'.format(Theil_U))
# Out:
# MAPE on validation data: 0.06
#
# R of validation data: 0.36
#
# Theil U of validation data: 0.04

# %%
#for plotting
train = new_data[:len(train)]
#train_pred = new_data[T:450]
valid = new_data[len(train):]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price.reshape(-1,1)
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.plot(train['Close'][len(train)-len(valid):], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()

# %%
#plt.plot(train['Close'][len(train)-len(valid):], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Close'][-(T_pred+T):], color = 'blue', label='Actual past stock price')
plt.plot(valid['Predictions'][-T_pred:], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'][-T_pred:], color = 'orange', label='Actual future stock price')
plt.legend()

# %%
rms1=np.sqrt(np.mean(np.power((valid['Predictions'][-T_pred:] - valid['Close'][-T_pred:]),2)))
print('RMS error of final prediction: {:.2f}'.format(rms1))
# Out:
# RMS error of final prediction: 10.58

# %%
inputs = new_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = np.reshape(inputs, (1,-1,1))
X_test.shape
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape

# %%
#Predictions on test set
closing_price = np.zeros((len(valid)))
X_test = []
for pred in range(len(closing_price)):
  #Single valued output
  if pred<T:
    X_test = new_data[len(train) - T + pred:len(train)].values
    X_test = X_test.reshape(-1,1)
    X_test = scaler.transform(X_test)
    if pred>0:
      X_test = np.concatenate((X_test, closing_price[:pred]), axis = None)  
  if pred>=T:
    X_test = closing_price[pred - T:pred]
  X_test = np.array(X_test)
  X_test = X_test.reshape(-1,1)
  #X_test  = scaler.transform(X_test)

  X_test = np.reshape(X_test, (X_test.shape[1],X_test.shape[0],1))
  closing_price[pred] = model.predict(X_test)
  #closing_price[pred] = scaler.inverse_transform(closing_price[pred]) 

closing_price = closing_price.reshape(-1,1)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape #single valued output prediction

# %%
print(closing_price.shape)
print(X_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (292, 1)
# (1, 90, 1)
# (710, 90, 1)
# (710,)

# %%
closing_price

# %%
#rms error
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
#np.mean(np.abs(valid - closing_price))
# Out:
# Close          163.078557
# Predictions    158.291392
# dtype: float64

# %%
#for plotting
train = new_data[:800]
#train_pred = new_data[T:450]
valid = new_data[800:]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
valid
# Out:
#               Close  Predictions
# Date
# 2019-11-01  1273.74  1244.864561
# 2019-11-04  1291.37  1235.571965
# 2019-11-05  1292.03  1225.102388
# 2019-11-06   1291.8  1212.246379
# 2019-11-07  1308.86  1201.619072
# ...             ...          ...
# 2020-07-14  1520.58  1195.485181
# 2020-07-15  1513.64  1195.874253
# 2020-07-16     1518  1196.312305
# 2020-07-17  1515.55  1196.774602
# 2020-07-20  1565.72  1197.242345
#
# [179 rows x 2 columns]

# %%
valid.to_csv('/content/drive/My Drive/Covid 19 part(2)/Results_1/TESLA_Predicted_vs_Actual_Stock_Prices_JULY.csv')

# %%
#Prediction for 22nd July, 2017
inputs = new_data[len(new_data) - T:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = inputs
X_test = X_test.reshape(1,T,1)

closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
print('Price on 22nd July : {}'.format(closing_price[0][0]))
# Out:
# Price on 22nd July : 1605.862060546875

# %%
#learning rate decay(picking optimum learning rate)
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss='mse', optimizer=optimizer)
history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-3, 0, 300])
#use this to choose the optimum lr and run the NN for 500 epochs

# %%
#Conv1D
tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [None,1])

# %%
#Converting the data in a df to float
df = df.astype('float64')

# %%
#concatenating two colums
data['date_time'] = data['date'].str.cat(data['time'], sep=' ')

# %%
#getting daily data from minute/hour wise data
df = df.resample('D').mean() # if we want mean of time data
df = df.resample('D').sum() # if we want sum of time data

# %%
#evaluate model for multi-step LSTM
def evaluate_model(y_true, y_predicted):
  scores = []

  #calculating score for each day
  for i in range(y_true.shape[1]):
    mse = mean_squared_error(y_true[:, i], y_predicted[:, i])
    rmse = np.sqrt(mse)
    scores.append(rmse)

  #calculating score for whole prediction
  total_score = 0
  for row in range(y_true.shape[0]):
    for col in range(y_predicted.shape[1]):
      total_score = total_score + (y_true[row,col] - y_predicted[row,col])**2
  total_score = np.sqrt(total_score/(y_true.shape[0]*y_predicted.shape[1]))

  return total_ score, scores

evaluate_model(y_true, y_pred)
np.std(y_true[0])

# %%
data = pd.read_csv('/content/drive/My Drive/Covid 19 part(2)/LSTM/AAPL_JAN18_JULY20.csv')
data
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [627 rows x 7 columns]

# %%
data_training = data[data['Date'] < '2019-12-31'].copy()
data_training
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 485  2019-12-23  280.529999  284.250000  ...  284.000000  282.562683  24643000
# 486  2019-12-24  284.690002  284.890015  ...  284.269989  282.831299  12119700
# 487  2019-12-26  284.820007  289.980011  ...  289.910004  288.442780  23280300
# 488  2019-12-27  291.119995  293.970001  ...  289.799988  288.333313  36566500
# 489  2019-12-30  289.459991  292.690002  ...  291.519989  290.044617  36028600
#
# [490 rows x 7 columns]

# %%
data_testing = data[data['Date'] >= '2019-12-31'].copy()
data_testing
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 490  2019-12-31  289.929993  293.679993  ...  293.649994  292.163818  25201400
# 491  2020-01-02  296.239990  300.600006  ...  300.350006  298.829956  33870100
# 492  2020-01-03  297.149994  300.579987  ...  297.429993  295.924713  36580700
# 493  2020-01-06  293.790009  299.959991  ...  299.799988  298.282715  29596800
# 494  2020-01-07  299.839996  300.899994  ...  298.390015  296.879883  27218000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [137 rows x 7 columns]

# %%
training_data = data_training.drop(['Date', 'Adj Close'], axis=1)
training_data
# Out:
#            Open        High         Low       Close    Volume
# 0    178.610001  179.580002  177.410004  178.460007  32425100
# 1    177.300003  177.779999  176.600006  177.000000  27108600
# 2    177.300003  179.440002  176.820007  177.039993  32689100
# 3    177.250000  177.300003  173.199997  174.220001  51105100
# 4    174.509995  174.949997  170.529999  171.110001  41529000
# ..          ...         ...         ...         ...       ...
# 485  280.529999  284.250000  280.369995  284.000000  24643000
# 486  284.690002  284.890015  282.920013  284.269989  12119700
# 487  284.820007  289.980011  284.700012  289.910004  23280300
# 488  291.119995  293.970001  288.119995  289.799988  36566500
# 489  289.459991  292.690002  285.220001  291.519989  36028600
#
# [490 rows x 5 columns]

# %%
scalar = MinMaxScaler()
training_data = scalar.fit_transform(training_data)
training_data.shape
# Out:
# (490, 5)

# %%
x_train = []
y_train = []

T = 60
for i in range(T, training_data.shape[0]):
  x_train.append(training_data[i-T:i])
  y_train.append(training_data[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (430, 60, 5)
# (430,)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, activation='tanh', input_shape=(x_train.shape[1],5)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=100, activation='tanh'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 60, 50)            11200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 91,901
# Trainable params: 91,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
start = time.time()
model.fit(x_train, y_train, epochs=50, batch_size=8)
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0159
# Epoch 2/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0041
# Epoch 3/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0029
# Epoch 4/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0030
# Epoch 5/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 6/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 7/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0024
# Epoch 8/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0024
# Epoch 9/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0038
# Epoch 10/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0022
# Epoch 11/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 12/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 13/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 14/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 15/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 16/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 17/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0017
# Epoch 18/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0018
# Epoch 19/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 20/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 21/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 22/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0016
# Epoch 23/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 24/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 25/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 26/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 27/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 28/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 29/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 30/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 31/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 32/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 33/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0014
# Epoch 34/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 35/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 36/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 37/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 38/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 39/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 40/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 41/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 42/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 43/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 44/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 45/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 46/50
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0011
# Epoch 47/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.8105e-04
# Epoch 48/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.4821e-04
# Epoch 49/50
# 54/54 [==============================] - 2s 40ms/step - loss: 8.9223e-04
# Epoch 50/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0010
# Run time: 1.929036263624827

# %%
past_T_days = data_training.tail(T)

df = past_T_days.append(data_testing, ignore_index = True)
df
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2019-10-04  225.639999  227.490005  ...  227.009995  225.185043  34619700
# 1    2019-10-07  226.270004  229.929993  ...  227.059998  225.234634  30576500
# 2    2019-10-08  225.820007  228.059998  ...  224.399994  222.596024  27955000
# 3    2019-10-09  227.029999  227.789993  ...  227.029999  225.204895  18692600
# 4    2019-10-10  227.929993  230.440002  ...  230.089996  228.240280  28253400
# ..          ...         ...         ...  ...         ...         ...       ...
# 192  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 193  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 194  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 195  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 196  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [197 rows x 7 columns]

# %%
df = df.drop(['Date', 'Adj Close'], axis=1)
df
# Out:
#            Open        High         Low       Close    Volume
# 0    225.639999  227.490005  223.889999  227.009995  34619700
# 1    226.270004  229.929993  225.839996  227.059998  30576500
# 2    225.820007  228.059998  224.330002  224.399994  27955000
# 3    227.029999  227.789993  225.639999  227.029999  18692600
# 4    227.929993  230.440002  227.300003  230.089996  28253400
# ..          ...         ...         ...         ...       ...
# 192  381.339996  383.920013  378.820007  383.679993  22564300
# 193  389.059998  399.820007  381.029999  381.910004  47912300
# 194  379.359985  389.019989  375.510010  388.230011  42747300
# 195  395.959991  396.989990  385.959991  390.899994  38299500
# 196  386.250000  389.619995  383.619995  386.089996  27644400
#
# [197 rows x 5 columns]

# %%
inputs = scalar.transform(df)
inputs.shape
# Out:
# (197, 5)
