# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#importing packages
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Lambda, Bidirectional, GRU, Conv1D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
#setting figure size
rcParams['figure.figsize'] = 20,10

#for normalizing data
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file
df = pd.read_csv('/content/drive/My Drive/LSTM/SPY_JULY15_JULY20.csv')

#df['Date'] = df[['Date', 'Time']].apply(lambda x: '-'.join(x), axis=1)
#print the head
df
# Out:
#             Date        Open        High  ...       Close   Adj Close     Volume
# 0     2015-07-27  206.940002  207.550003  ...  206.789993  187.214249  132361100
# 1     2015-07-28  207.789993  209.500000  ...  209.330002  189.513840  123544800
# 2     2015-07-29  209.479996  211.039993  ...  210.770004  190.817490  105791300
# 3     2015-07-30  210.160004  211.020004  ...  210.820007  190.862778   91304400
# 4     2015-07-31  211.419998  211.449997  ...  210.500000  190.573059  103266900
# ...          ...         ...         ...  ...         ...         ...        ...
# 1254  2020-07-20  321.429993  325.130005  ...  324.320007  324.320007   56308800
# 1255  2020-07-21  326.450012  326.929993  ...  325.010010  325.010010   57499000
# 1256  2020-07-22  324.619995  327.200012  ...  326.859985  326.859985   57792900
# 1257  2020-07-23  326.470001  327.230011  ...  322.959991  322.959991   75738000
# 1258  2020-07-24  320.950012  321.989990  ...  320.880005  320.880005   73724200
#
# [1259 rows x 7 columns]

# %%
#setting index as date
#df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df['Date'] = pd.to_datetime(df.Date)
df.index = df['Date']
#df = df[df['Date'] < '2020-01-01']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')
plt.legend()

# %%
#creating dataframe
T = 30 #training period
T_pred = 30 #prediction period

data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close', 'Open', 'Volume'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]
    new_data['Open'][i] = data['Open'][i]
    new_data['Volume'][i] = data['Volume'][i]

#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

num_classes = len(new_data.columns)

#creating train and test sets
dataset = new_data.values

train_total = dataset[:-T_pred,:]
valid = dataset[-T_pred:,0].reshape(-1,1)

#train = train_total[:-(T_pred+T),:]
train = train_total
test = train_total[-(T_pred+T):,:]


train.shape, valid.shape, test.shape, dataset.shape
# Out:
# ((1229, 3), (30, 1), (60, 3), (1259, 3))

# %%
new_data
# Out:
#              Close    Open     Volume
# Date
# 2015-07-27  206.79  206.94  132361100
# 2015-07-28  209.33  207.79  123544800
# 2015-07-29  210.77  209.48  105791300
# 2015-07-30  210.82  210.16   91304400
# 2015-07-31   210.5  211.42  103266900
# ...            ...     ...        ...
# 2020-07-20  324.32  321.43   56308800
# 2020-07-21  325.01  326.45   57499000
# 2020-07-22  326.86  324.62   57792900
# 2020-07-23  322.96  326.47   75738000
# 2020-07-24  320.88  320.95   73724200
#
# [1259 rows x 3 columns]

# %%
scaled_data.shape
# Out:
# (1117, 3)

# %%
len(new_data.columns)
# Out:
# 3

# %%
dataset.shape
# Out:
# (1117, 3)

# %%
len(dataset)
# Out:
# 1117

# %%
dataset[:,1].shape
# Out:
# (1117,)

# %%
scaled_data = np.zeros((len(dataset), num_classes))
scaled_data[:,i].shape
# Out:
# (1117,)

# %%
scaler.fit_transform(dataset[:,0].reshape(-1,1))
# Out:
# (1117, 1)

# %%
#converting dataset into x_train and y_train
# T = 30 #training period
# T_pred = T
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = np.zeros((len(dataset), num_classes))
for i in range(num_classes-1,-1,-1):
  scaled_data[:,i] = np.squeeze(scaler.fit_transform(dataset[:,i].reshape(-1,1)))

x_train, y_train = [], []
for i in range(T,len(train)-T_pred):
    x_train.append(scaled_data[i-T:i,:])
    y_train.append(scaled_data[i:i+T_pred,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],num_classes))
#y_train = np.reshape(y_train, (y_train.shape[0],y_train.shape[1],1))
print(x_train.shape, y_train.shape)
# Out:
# (1169, 30, 3) (1169, 30)

# %%
for i in range(5,-1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
scaler.scale_
# Out:
# array([2.05349646e-09])

# %%
scaler.scale_
# Out:
# array([0.00713878])

# %%
scaler.scale_
# Out:
# array([7.13877779e-03, 7.07213609e-03, 2.05349646e-09])

# %%
test.shape
# Out:
# (90, 3)

# %%
#creating validation data
scaler_test = MinMaxScaler(feature_range=(0, 1))
test_scaled = np.zeros((len(test), num_classes))
for i in range(num_classes):
  test_scaled[:,i] = np.squeeze(scaler_test.fit_transform(test[:,i].reshape(-1,1)))

x_test = test_scaled[:T,:].reshape(1,-1,num_classes)
y_test = test_scaled[T:T+T_pred,0].reshape(1,-1)

# %%
x_test.shape, y_test.shape
# Out:
# ((1, 30, 3), (1, 60))

# %%
scaler.scale_
# Out:
# array([2.05349646e-09])

# %%
# create and fit the LSTM network
model = Sequential()
model.add(Conv1D(filters=90, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [T,num_classes]))
model.add(LSTM(units=90, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(units=90, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=150, activation='tanh'))
model.add(Dense(T_pred))
#model.add(Lambda(lambda x: x*500))

#model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001))
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
checkpoint = ModelCheckpoint(weight_save_path+model_name+'.h5', monitor='val_accuracy', save_best_only=True, save_weights_only=True, )
model.compile(loss=Huber(), optimizer=Adam(lr=0.001), metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 30, 90)            1440
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 30, 90)            65160
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 30, 90)            0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 30, 90)            65160
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 30, 90)            0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 150)               144600
# _________________________________________________________________
# dense_18 (Dense)             (None, 60)                9060
# =================================================================
# Total params: 285,420
# Trainable params: 285,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create and fit the LSTM network
model_name = '4_CONV_3_LSTM_2_DENSE_3_class_SPY_JULY15_JAN20'
weight_save_path = '/content/drive/My Drive/LSTM/Results/'

model = Sequential()
model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [T,num_classes]))
model.add(BatchNormalization())
model.add(Conv1D(filters=300, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(filters=200, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
model.add(Conv1D(filters=200, kernel_size=5, strides=1, padding='causal', activation='relu'))
model.add(BatchNormalization())
# model.add(LSTM(units=300, return_sequences=True, activation='tanh'))
# model.add(Dropout(0.1))
#model.add(BatchNormalization())
# model.add(LSTM(units=250, activation='tanh', return_sequences=True))
# model.add(Dropout(0.2))
#model.add(BatchNormalization())
model.add(LSTM(units=150, activation='tanh', return_sequences= True))
model.add(Dropout(0.2))
#model.add(BatchNormalization())
model.add(LSTM(units=150, activation='tanh', return_sequences= True))
model.add(Dropout(0.5))
#model.add(BatchNormalization())
model.add(LSTM(units=100, activation='tanh'))
model.add(Dense(100))
model.add(Dropout(0.2))
model.add(Dense(20))
model.add(Dense(T_pred))
#model.add(Lambda(lambda x: x*500))


model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001), metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_33 (Conv1D)           (None, 30, 300)           4800
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 30, 300)           1200
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 30, 300)           450300
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 30, 300)           1200
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 30, 200)           300200
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 30, 200)           800
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 30, 200)           200200
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 30, 200)           800
# _________________________________________________________________
# lstm_63 (LSTM)               (None, 30, 150)           210600
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 30, 150)           0
# _________________________________________________________________
# lstm_64 (LSTM)               (None, 30, 150)           180600
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 30, 150)           0
# _________________________________________________________________
# lstm_65 (LSTM)               (None, 100)               100400
# _________________________________________________________________
# dense_43 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_45 (Dense)             (None, 30)                630
# =================================================================
# Total params: 1,463,850
# Trainable params: 1,461,850
# Non-trainable params: 2,000
# _________________________________________________________________

# %%
#callbacks
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
checkpoint = ModelCheckpoint(weight_save_path+model_name+'.h5', monitor='val_loss', save_best_only=True, save_weights_only=True, )

# %%
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=[lr_schedule])
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 21ms/step - loss: 0.2303 - mae: 0.4319 - lr: 1.0000e-08
# Epoch 2/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2302 - mae: 0.4316 - lr: 1.1220e-08
# Epoch 3/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2305 - mae: 0.4320 - lr: 1.2589e-08
# Epoch 4/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2303 - mae: 0.4316 - lr: 1.4125e-08
# Epoch 5/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2303 - mae: 0.4317 - lr: 1.5849e-08
# Epoch 6/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2301 - mae: 0.4316 - lr: 1.7783e-08
# Epoch 7/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2300 - mae: 0.4315 - lr: 1.9953e-08
# Epoch 8/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2301 - mae: 0.4316 - lr: 2.2387e-08
# Epoch 9/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2301 - mae: 0.4316 - lr: 2.5119e-08
# Epoch 10/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2297 - mae: 0.4313 - lr: 2.8184e-08
# Epoch 11/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2298 - mae: 0.4315 - lr: 3.1623e-08
# Epoch 12/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2294 - mae: 0.4311 - lr: 3.5481e-08
# Epoch 13/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2293 - mae: 0.4310 - lr: 3.9811e-08
# Epoch 14/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2289 - mae: 0.4306 - lr: 4.4668e-08
# Epoch 15/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2288 - mae: 0.4304 - lr: 5.0119e-08
# Epoch 16/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2288 - mae: 0.4304 - lr: 5.6234e-08
# Epoch 17/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2284 - mae: 0.4301 - lr: 6.3096e-08
# Epoch 18/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2280 - mae: 0.4298 - lr: 7.0795e-08
# Epoch 19/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2276 - mae: 0.4296 - lr: 7.9433e-08
# Epoch 20/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2273 - mae: 0.4291 - lr: 8.9125e-08
# Epoch 21/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2269 - mae: 0.4289 - lr: 1.0000e-07
# Epoch 22/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2264 - mae: 0.4283 - lr: 1.1220e-07
# Epoch 23/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2263 - mae: 0.4283 - lr: 1.2589e-07
# Epoch 24/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2255 - mae: 0.4275 - lr: 1.4125e-07
# Epoch 25/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2244 - mae: 0.4266 - lr: 1.5849e-07
# Epoch 26/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2241 - mae: 0.4265 - lr: 1.7783e-07
# Epoch 27/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2228 - mae: 0.4251 - lr: 1.9953e-07
# Epoch 28/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2224 - mae: 0.4247 - lr: 2.2387e-07
# Epoch 29/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2215 - mae: 0.4238 - lr: 2.5119e-07
# Epoch 30/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2203 - mae: 0.4226 - lr: 2.8184e-07
# Epoch 31/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0
100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0853 - mae: 0.2092 - lr: 2.5119e-05
# Epoch 70/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0792 - mae: 0.2004 - lr: 2.8184e-05
# Epoch 71/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0727 - mae: 0.1903 - lr: 3.1623e-05
# Epoch 72/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0656 - mae: 0.1798 - lr: 3.5481e-05
# Epoch 73/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0584 - mae: 0.1683 - lr: 3.9811e-05
# Epoch 74/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0517 - mae: 0.1581 - lr: 4.4668e-05
# Epoch 75/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0450 - mae: 0.1490 - lr: 5.0119e-05
# Epoch 76/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0383 - mae: 0.1372 - lr: 5.6234e-05
# Epoch 77/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0322 - mae: 0.1269 - lr: 6.3096e-05
# Epoch 78/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0273 - mae: 0.1175 - lr: 7.0795e-05
# Epoch 79/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0216 - mae: 0.1054 - lr: 7.9433e-05
# Epoch 80/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0183 - mae: 0.0980 - lr: 8.9125e-05
# Epoch 81/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0160 - mae: 0.0936 - lr: 1.0000e-04
# Epoch 82/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0139 - mae: 0.0874 - lr: 1.1220e-04
# Epoch 83/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0130 - mae: 0.0852 - lr: 1.2589e-04
# Epoch 84/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0121 - mae: 0.0821 - lr: 1.4125e-04
# Epoch 85/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0109 - mae: 0.0786 - lr: 1.5849e-04
# Epoch 86/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0101 - mae: 0.0754 - lr: 1.7783e-04
# Epoch 87/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0094 - mae: 0.0724 - lr: 1.9953e-04
# Epoch 88/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0092 - mae: 0.0734 - lr: 2.2387e-04
# Epoch 89/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0092 - mae: 0.0728 - lr: 2.5119e-04
# Epoch 90/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0078 - mae: 0.0662 - lr: 2.8184e-04
# Epoch 91/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0073 - mae: 0.0642 - lr: 3.1623e-04
# Epoch 92/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0072 - mae: 0.0640 - lr: 3.5481e-04
# Epoch 93/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0066 - mae: 0.0618 - lr: 3.9811e-04
# Epoch 94/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0067 - mae: 0.0625 - lr: 4.4668e-04
# Epoch 95/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0061 - mae: 0.0593 - lr: 5.0119e-04
# Epoch 96/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0060 - mae: 0.0592 - lr: 5.6234e-04
# Epoch 97/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0064 - mae: 0.0613 - lr: 6.3096e-04
# Epoch 98/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0054 - mae: 0.0558 - lr: 7.0795e-04
# Epoch 99/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0068 - mae: 0.0630 - lr: 7.9433e-04
# Epoch 100/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0050 - mae: 0.0534 - lr: 8.9125e-04
# Run time: 1.1019793391227721

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-2, 0, 1])
#use this to choose the optimum lr and run the NN for 500 epochs
# Out:
# (1e-08, 0.01, 0.0, 1.0)

# %%
class stop_training(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if (logs.get('loss')<0.00001):
      print("Stopping training")
      self.model.stop_training = True

stop_training = stop_training()
model.compile(loss='mse', optimizer=Adam(lr=1e-3), metrics=['mae'])
import time
start = time.time()
history = model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_test, y_test), callbacks=[checkpoint, stop_training])
end = time.time()
# Epoch 200/200
# 37/37 [==============================] - 1s 14ms/step - loss: 6.9922e-04 - mae: 0.0194 - val_loss: 0.0071 - val_mae: 0.0714
# Run time: 1.9459630767504374

# %%
model.load_weights(weight_save_path+model_name+'.h5')

# %%
# #predicting 246 values, using past 60 from the train data
# inputs = new_data[len(new_data) - len(valid) - T:].values
# inputs = inputs.reshape(-1,1)
# inputs  = scaler.transform(inputs)

# X_test = []
# for i in range(T,inputs.shape[0]):
#     X_test.append(inputs[i-T:i,0])
# X_test = np.array(X_test)

# X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
# closing_price = model.predict(X_test)
# closing_price = scaler.inverse_transform(closing_price)

# %%
scaled_data.shape
# Out:
# (1117, 3)

# %%
len(new_data) - len(valid)
# Out:
# 1057

# %%
inputs = scaled_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)]
inputs = inputs.reshape(-1,num_classes)
inputs.shape
scale
# Out:
# 140.08000099999998

# %%
inputs.shape
# Out:
# (30, 1)

# %%
inputs = scaled_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)]
inputs = inputs.reshape(-1,num_classes)

#inputs  = scaler.transform(inputs)
X_test = np.reshape(inputs, (1,-1,num_classes))

closing_price = model.predict(X_test)

closing_price = scaler.inverse_transform(closing_price)
closing_price.shape
# Out:
# (1, 30)

# %%
closing_price
# Out:
# array([[282.3814 , 282.94016, 282.3162 , 282.1842 , 282.70718, 282.9356 ,
#         282.4819 , 282.67682, 282.46146, 281.91367, 282.29468, 282.23386,
#         282.18762, 282.5706 , 280.3354 , 282.47128, 281.69083, 281.82043,
#         281.10846, 281.90433, 280.8476 , 282.1254 , 281.91644, 282.129  ,
#         281.2456 , 281.02057, 281.42615, 282.18146, 283.39883, 282.8932 ]],
#       dtype=float32)

# %%
print(closing_price.shape)
print(X_test.shape)
print(valid.shape)
# Out:
# (1, 60)
# (1, 30, 3)
# (60, 1)

# %%
#rms error
rms=np.sqrt(np.mean(np.power((valid.reshape(1,-1) - closing_price),2)))
rms
#np.mean(np.abs(valid - closing_price))
# Out:
# 32.77985046014861

# %%
np.std(valid)
# Out:
# 6.866453355355933

# %%
#for plotting
train = new_data[:-T_pred]
#train_pred = new_data[T:450]
valid = new_data[-T_pred:]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price.reshape(-1,1)
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
inputs = new_data[len(new_data) - len(valid) - T:len(new_data) - len(valid)].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = np.reshape(inputs, (1,-1,1))
X_test.shape
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape

# %%
#Predictions on test set
closing_price = np.zeros((len(valid)))
X_test = []
for pred in range(len(closing_price)):
  #Single valued output
  if pred<T:
    X_test = new_data[len(train) - T + pred:len(train)].values
    X_test = X_test.reshape(-1,1)
    X_test = scaler.transform(X_test)
    if pred>0:
      X_test = np.concatenate((X_test, closing_price[:pred]), axis = None)  
  if pred>=T:
    X_test = closing_price[pred - T:pred]
  X_test = np.array(X_test)
  X_test = X_test.reshape(-1,1)
  #X_test  = scaler.transform(X_test)

  X_test = np.reshape(X_test, (X_test.shape[1],X_test.shape[0],1))
  closing_price[pred] = model.predict(X_test)
  #closing_price[pred] = scaler.inverse_transform(closing_price[pred]) 

closing_price = closing_price.reshape(-1,1)
closing_price = scaler.inverse_transform(closing_price)
closing_price.shape #single valued output prediction

# %%
print(closing_price.shape)
print(X_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (292, 1)
# (1, 90, 1)
# (710, 90, 1)
# (710,)

# %%
closing_price

# %%
#rms error
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
#np.mean(np.abs(valid - closing_price))
# Out:
# Close          163.078557
# Predictions    158.291392
# dtype: float64

# %%
#for plotting
train = new_data[:800]
#train_pred = new_data[T:450]
valid = new_data[800:]
#train_pred['Predictions'] = closing_price_train
valid['Predictions'] = closing_price
plt.plot(train['Close'], color='blue', label='Actual past stock price')
#plt.plot(train_pred['Predictions'], color='red', label='Predicted past stock price')
#plt.plot(valid['Predictions'], label='Predicted stock price')
plt.plot(valid['Predictions'], color = 'green', label='Predicted future stock price')
plt.plot(valid['Close'], color = 'orange', label='Actual future stock price')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
valid
# Out:
#               Close  Predictions
# Date
# 2019-11-01  1273.74  1244.864561
# 2019-11-04  1291.37  1235.571965
# 2019-11-05  1292.03  1225.102388
# 2019-11-06   1291.8  1212.246379
# 2019-11-07  1308.86  1201.619072
# ...             ...          ...
# 2020-07-14  1520.58  1195.485181
# 2020-07-15  1513.64  1195.874253
# 2020-07-16     1518  1196.312305
# 2020-07-17  1515.55  1196.774602
# 2020-07-20  1565.72  1197.242345
#
# [179 rows x 2 columns]

# %%
valid.to_csv('/content/drive/My Drive/Covid 19 part(2)/Results_1/TESLA_Predicted_vs_Actual_Stock_Prices_JULY.csv')

# %%
#Prediction for 22nd July, 2017
inputs = new_data[len(new_data) - T:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = inputs
X_test = X_test.reshape(1,T,1)

closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
print('Price on 22nd July : {}'.format(closing_price[0][0]))
# Out:
# Price on 22nd July : 1605.862060546875

# %%
#learning rate decay(picking optimum learning rate)
lr_schedule = tf.keras.callbacks.LearningRateScheduler( lambda epoch: 1e-8 * 10**(epoch/ 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss='mse', optimizer=optimizer)
history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])

# %%
#plotting loss per epoch against learning rate
lrs = 1e-8 * (10 ** (np.arange(100)/20))
plt.semilogx(lrs, history.history['loss'])
plt.axis([1e-8, 1e-3, 0, 300])
#use this to choose the optimum lr and run the NN for 500 epochs

# %%
#Conv1D
tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding='causal', activation='relu', input_shape = [None,1])

# %%
#Converting the data in a df to float
df = df.astype('float64')

# %%
#concatenating two colums
data['date_time'] = data['date'].str.cat(data['time'], sep=' ')

# %%
#getting daily data from minute/hour wise data
df = df.resample('D').mean() # if we want mean of time data
df = df.resample('D').sum() # if we want sum of time data

# %%
#evaluate model for multi-step LSTM
def evaluate_model(y_true, y_predicted):
  scores = []

  #calculating score for each day
  for i in range(y_true.shape[1]):
    mse = mean_squared_error(y_true[:, i], y_predicted[:, i])
    rmse = np.sqrt(mse)
    scores.append(rmse)

  #calculating score for whole prediction
  total_score = 0
  for row in range(y_true.shape[0]):
    for col in range(y_predicted.shape[1]):
      total_score = total_score + (y_true[row,col] - y_predicted[row,col])**2
  total_score = np.sqrt(total_score/(y_true.shape[0]*y_predicted.shape[1]))

  return total_ score, scores

evaluate_model(y_true, y_pred)
np.std(y_true[0])

# %%
data = pd.read_csv('/content/drive/My Drive/Covid 19 part(2)/LSTM/AAPL_JAN18_JULY20.csv')
data
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [627 rows x 7 columns]

# %%
data_training = data[data['Date'] < '2019-12-31'].copy()
data_training
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2018-01-19  178.610001  179.580002  ...  178.460007  172.341141  32425100
# 1    2018-01-22  177.300003  177.779999  ...  177.000000  170.931198  27108600
# 2    2018-01-23  177.300003  179.440002  ...  177.039993  170.969803  32689100
# 3    2018-01-24  177.250000  177.300003  ...  174.220001  168.246521  51105100
# 4    2018-01-25  174.509995  174.949997  ...  171.110001  165.243134  41529000
# ..          ...         ...         ...  ...         ...         ...       ...
# 485  2019-12-23  280.529999  284.250000  ...  284.000000  282.562683  24643000
# 486  2019-12-24  284.690002  284.890015  ...  284.269989  282.831299  12119700
# 487  2019-12-26  284.820007  289.980011  ...  289.910004  288.442780  23280300
# 488  2019-12-27  291.119995  293.970001  ...  289.799988  288.333313  36566500
# 489  2019-12-30  289.459991  292.690002  ...  291.519989  290.044617  36028600
#
# [490 rows x 7 columns]

# %%
data_testing = data[data['Date'] >= '2019-12-31'].copy()
data_testing
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 490  2019-12-31  289.929993  293.679993  ...  293.649994  292.163818  25201400
# 491  2020-01-02  296.239990  300.600006  ...  300.350006  298.829956  33870100
# 492  2020-01-03  297.149994  300.579987  ...  297.429993  295.924713  36580700
# 493  2020-01-06  293.790009  299.959991  ...  299.799988  298.282715  29596800
# 494  2020-01-07  299.839996  300.899994  ...  298.390015  296.879883  27218000
# ..          ...         ...         ...  ...         ...         ...       ...
# 622  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 623  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 624  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 625  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 626  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [137 rows x 7 columns]

# %%
training_data = data_training.drop(['Date', 'Adj Close'], axis=1)
training_data
# Out:
#            Open        High         Low       Close    Volume
# 0    178.610001  179.580002  177.410004  178.460007  32425100
# 1    177.300003  177.779999  176.600006  177.000000  27108600
# 2    177.300003  179.440002  176.820007  177.039993  32689100
# 3    177.250000  177.300003  173.199997  174.220001  51105100
# 4    174.509995  174.949997  170.529999  171.110001  41529000
# ..          ...         ...         ...         ...       ...
# 485  280.529999  284.250000  280.369995  284.000000  24643000
# 486  284.690002  284.890015  282.920013  284.269989  12119700
# 487  284.820007  289.980011  284.700012  289.910004  23280300
# 488  291.119995  293.970001  288.119995  289.799988  36566500
# 489  289.459991  292.690002  285.220001  291.519989  36028600
#
# [490 rows x 5 columns]

# %%
scalar = MinMaxScaler()
training_data = scalar.fit_transform(training_data)
training_data.shape
# Out:
# (490, 5)

# %%
x_train = []
y_train = []

T = 60
for i in range(T, training_data.shape[0]):
  x_train.append(training_data[i-T:i])
  y_train.append(training_data[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (430, 60, 5)
# (430,)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, activation='tanh', input_shape=(x_train.shape[1],5)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=100, activation='tanh'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 60, 50)            11200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 91,901
# Trainable params: 91,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
start = time.time()
model.fit(x_train, y_train, epochs=50, batch_size=8)
end = time.time()
print('Run time: {}'.format((end-start)/60))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0159
# Epoch 2/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0041
# Epoch 3/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0029
# Epoch 4/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0030
# Epoch 5/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 6/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 7/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0024
# Epoch 8/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0024
# Epoch 9/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0038
# Epoch 10/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0022
# Epoch 11/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 12/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 13/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 14/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 15/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 16/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0019
# Epoch 17/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0017
# Epoch 18/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0018
# Epoch 19/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 20/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 21/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 22/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0016
# Epoch 23/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 24/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 25/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 26/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 27/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 28/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0015
# Epoch 29/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 30/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 31/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 32/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 33/50
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0014
# Epoch 34/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 35/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 36/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 37/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 38/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 39/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 40/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 41/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 42/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 43/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 44/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 45/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0011
# Epoch 46/50
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0011
# Epoch 47/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.8105e-04
# Epoch 48/50
# 54/54 [==============================] - 2s 40ms/step - loss: 9.4821e-04
# Epoch 49/50
# 54/54 [==============================] - 2s 40ms/step - loss: 8.9223e-04
# Epoch 50/50
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0010
# Run time: 1.929036263624827

# %%
past_T_days = data_training.tail(T)

df = past_T_days.append(data_testing, ignore_index = True)
df
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2019-10-04  225.639999  227.490005  ...  227.009995  225.185043  34619700
# 1    2019-10-07  226.270004  229.929993  ...  227.059998  225.234634  30576500
# 2    2019-10-08  225.820007  228.059998  ...  224.399994  222.596024  27955000
# 3    2019-10-09  227.029999  227.789993  ...  227.029999  225.204895  18692600
# 4    2019-10-10  227.929993  230.440002  ...  230.089996  228.240280  28253400
# ..          ...         ...         ...  ...         ...         ...       ...
# 192  2020-07-10  381.339996  383.920013  ...  383.679993  383.679993  22564300
# 193  2020-07-13  389.059998  399.820007  ...  381.910004  381.910004  47912300
# 194  2020-07-14  379.359985  389.019989  ...  388.230011  388.230011  42747300
# 195  2020-07-15  395.959991  396.989990  ...  390.899994  390.899994  38299500
# 196  2020-07-16  386.250000  389.619995  ...  386.089996  386.089996  27644400
#
# [197 rows x 7 columns]

# %%
df = df.drop(['Date', 'Adj Close'], axis=1)
df
# Out:
#            Open        High         Low       Close    Volume
# 0    225.639999  227.490005  223.889999  227.009995  34619700
# 1    226.270004  229.929993  225.839996  227.059998  30576500
# 2    225.820007  228.059998  224.330002  224.399994  27955000
# 3    227.029999  227.789993  225.639999  227.029999  18692600
# 4    227.929993  230.440002  227.300003  230.089996  28253400
# ..          ...         ...         ...         ...       ...
# 192  381.339996  383.920013  378.820007  383.679993  22564300
# 193  389.059998  399.820007  381.029999  381.910004  47912300
# 194  379.359985  389.019989  375.510010  388.230011  42747300
# 195  395.959991  396.989990  385.959991  390.899994  38299500
# 196  386.250000  389.619995  383.619995  386.089996  27644400
#
# [197 rows x 5 columns]

# %%
inputs = scalar.transform(df)
inputs.shape
# Out:
# (197, 5)
